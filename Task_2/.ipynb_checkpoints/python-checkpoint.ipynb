# %%
import os

import pandas as pd
import Python as py

# %%
import importlib
import Python as py

# %%
root = os.getcwd()
df_scheduled = pd.read_csv(root + "/data/scheduled_loan_repayments.csv")
df_actual = pd.read_csv(root + "/data/actual_loan_repayments.csv")
df_balances = py.calculate_df_balances(df_scheduled, df_actual)

# %%
importlib.reload(py)
# Out:
# <module 'Python' from '/app/Task_2/Python.py'>

# %%
print(dir(py))
# Out:
# ['__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', '__warningregistry__', 'calculate_df_balances', 'df_actual', 'df_balances', 'df_scheduled', 'np', 'os', 'pd', 'question_1', 'question_2', 'question_3', 'question_4', 'root']

# %%
py.question_4(py.df_balances)
# Out:
# 85119.70593599998
